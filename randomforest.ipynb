# %%
#Importing our dataset from csv file
import pandas as pd 
dataset=pd.read_csv("titanic-passengers.csv", sep=";")

#Preprocessing our data
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(dataset)

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    1  28.0      0      0      248740  13.0000     G6        S
# 1    1  25.0      0      0      348123   7.6500  F G73        S
# 2    1  20.0      0      0      350050   7.8542     G6        S
# 3    0  29.0      0      4      349909  21.0750     G6        S
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
#importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked","Cabin"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
tree = tree.DecisionTreeClassifier()  
tree.fit(x_train, y_train)   #fitting our model
y_pred=tree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.776536312849162

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
#from sklearn.datasets import load_dataset
from sklearn import tree

# %%
#clf = tree.DecisionTreeClassifier(random_state=0)
clf = tree.DecisionTreeClassifier(criterion = "gini", splitter = 'random', max_leaf_nodes = 10, min_samples_leaf = 5, max_depth= 5)

# %%
plt.figure(figsize=(150,100))
#plt.title("Decision trees on the Shakespear dataset (Gini)")
clf = clf.fit(x,y)
tree.plot_tree(clf,precision=3,fontsize=20,proportion=True,filled=True)
plt.show()

# %%
""""we used pruning to avoid overfitting ,x[2] is the root node ,moving down left the tree means that the answewr of the internal 
node is yes 
#x[0],x[1],x[2] are parameters that are chosen so we can split them .
#as we reached the leaf nodes gini become zero which means that all samples are from the same class"""
# Out:
# '"we used pruning to avoid overfitting ,x[2] is the root node ,moving down left the tree means that the answewr of the internal \nnode is yes \n#x[0],x[1],x[2] are parameters that are chosen so we can split them .\n#as we reached the leaf nodes gini become zero which means that all samples are from the same class'

# %%
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked","Cabin","Parch","Pclass"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
tree = tree.DecisionTreeClassifier()  
tree.fit(x_train, y_train)   #fitting our model
y_pred=tree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7932960893854749

# %%
#when dropping Parch and Pclass the accurcy inreased from 0.75 to almost 0.8

# %%
from sklearn import datasets
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier #Importing Random Forest Classifier
from sklearn import metrics  # Importing metrics to test accuracy
dataset=pd.read_csv("titanic-passengers.csv", sep=";")
#m = pd.read_cvs("titanic-passengers.csv", sep=";")

data=dataset.DataFrame({
'Age': dataset.data[:,0],
'Sex': dataset.data[:,1],
'Parch': dataset.data[:,2],
'Pclass': dataset.data[:,3], 
'Survived': dataset.target
})

X=data[['Age', 'Sex', 'Parch', 'Pclass']] #features
y=data['Survived']  #target
x_train, x_test, y_train, y_test= train_test_split(X, y, test_size=0.3) #
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 9>()
#       6 dataset=pd.read_csv("titanic-passengers.csv", sep=";")
#       7 #m = pd.read_cvs("titanic-passengers.csv", sep=";")
# ----> 9 data=dataset.DataFrame({
#      10 'Age': dataset.data[:,0],
#      11 'Sex': dataset.data[:,1],
#      12 'Parch': dataset.data[:,2],
#      13 'Pclass': dataset.data[:,3],
#      14 'Survived': dataset.target
#      15 })
#      17 X=data[['Age', 'Sex', 'Parch', 'Pclass']] #features
#      18 y=data['Survived']  #target
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
# ...
